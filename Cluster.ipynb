# %%
import pandas as pd
import os

# %%
gps = "Data/gps.csv"
games = "Data/games.csv"
wellness = "Data/wellness.csv"
rpe = "Data/rpe.csv"

# %%
gps_data = pd.read_csv(gps)
games_data = pd.read_csv(games)
wellness_data = pd.read_csv(wellness)
rpe_data = pd.read_csv(rpe)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-13e79e5c7cbb> in <module>
# ----> 1 gps_data = pd.read_csv(gps)
#       2 games_data = pd.read_csv(games)
#       3 wellness_data = pd.read_csv(wellness)
#       4 rpe_data = pd.read_csv(rpe)
#
# ...

# %%
newdf = pd.concat([games_data, rpe_data], axis =1, join = 'inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f42ddbd3cd20> in <module>
# ----> 1 newdf = pd.concat([games_data, rpe_data], axis =1, join = 'inner')
#
# NameError: name 'games_data' is not defined

# %%
print(newdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-82f7fdecabe6> in <module>
# ----> 1 print(newdf)
#
# NameError: name 'newdf' is not defined

# %%
# Out:
#    GameID        Date Tournament  TournamentGame    Team   Opponent Outcome  \
# 0       1  2017-11-30      Dubai               1  Canada      Spain       W
# 1       2  2017-11-30      Dubai               2  Canada    Ireland       W
# 2       3  2017-11-30      Dubai               3  Canada       Fiji       W
# 3       4  2017-12-01      Dubai               4  Canada     France       W
# 4       5  2017-12-01      Dubai               5  Canada  Australia       L
#
#    TeamPoints  TeamPointsAllowed        Date  ...  Duration  RPE SessionLoad  \
# 0          19                  0  2018-07-21  ...       5.0  0.0         0.0
# 1          31                  0  2018-07-21  ...      29.0  7.0       203.0
# 2          31                 14  2018-07-21  ...      27.0  9.0       243.0
# 3          24                 19  2018-07-20  ...      36.0  6.0       216.0
# 4           7                 25  2018-07-20  ...      36.0  8.0       288.0
#
# ...

# %%
newdf = pd.merge(rpe_data, games_data, how = 'left', on = 'Date')

# %%
newdf.head(20)
# Out:
#     GameID        Date    Tournament  TournamentGame    Team      Opponent  \
# 0        1  2017-11-30         Dubai               1  Canada         Spain
# 1        2  2017-11-30         Dubai               2  Canada       Ireland
# 2        3  2017-11-30         Dubai               3  Canada          Fiji
# 3        4  2017-12-01         Dubai               4  Canada        France
# 4        5  2017-12-01         Dubai               5  Canada     Australia
# 5        6  2017-12-01         Dubai               6  Canada        Russia
# 6        7  2018-01-26        Sydney               1  Canada          Fiji
# 7        8  2018-01-26        Sydney               2  Canada       Ireland
# 8        9  2018-01-26        Sydney               3  Canada        Russia
# 9       10  2018-01-27        Sydney               4  Canada        France
# 10      11  2018-01-27        Sydney               5  Canada   New Zealand
# ...

# %%
print(newdf)
# Out:
#             Date  PlayerID Training        SessionType  Duration  RPE  \
# 0     2018-07-21        13      Yes  Mobility/Recovery       5.0  0.0
# 1     2018-07-21        13      Yes  Mobility/Recovery       5.0  0.0
# 2     2018-07-21        13      Yes               Game      29.0  7.0
# 3     2018-07-21        13      Yes               Game      29.0  7.0
# 4     2018-07-21        13      Yes               Game      27.0  9.0
# 5     2018-07-21        13      Yes               Game      27.0  9.0
# 6     2018-07-20        11      Yes               Game      36.0  6.0
# 7     2018-07-20        11      Yes               Game      36.0  6.0
# 8     2018-07-20        11      Yes               Game      36.0  8.0
# 9     2018-07-20        11      Yes               Game      36.0  8.0
# 10    2018-07-20        11      Yes  Mobility/Recovery      15.0  2.0
# 11    2018-07-20        11      Yes  Mobility/Recovery      15.0  2.0
# ...

# %%
export_CSV = newdf.to_csv(r'newdf.csv', header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3bceb7d7950e> in <module>
# ----> 1 export_CSV = newdf.to_csv(r'newdf.csv', header = True)
#
# NameError: name 'newdf' is not defined

# %%
anothernewdf = pd.merge(rpe_data, games_data, how = 'left', on = 'Date')

# %%
anothernewdf.head(30)
# Out:
#           Date  PlayerID Training        SessionType  Duration  RPE  \
# 0   2018-07-21        13      Yes  Mobility/Recovery       5.0  0.0
# 1   2018-07-21        13      Yes  Mobility/Recovery       5.0  0.0
# 2   2018-07-21        13      Yes               Game      29.0  7.0
# 3   2018-07-21        13      Yes               Game      29.0  7.0
# 4   2018-07-21        13      Yes               Game      27.0  9.0
# 5   2018-07-21        13      Yes               Game      27.0  9.0
# 6   2018-07-20        11      Yes               Game      36.0  6.0
# 7   2018-07-20        11      Yes               Game      36.0  6.0
# 8   2018-07-20        11      Yes               Game      36.0  8.0
# 9   2018-07-20        11      Yes               Game      36.0  8.0
# 10  2018-07-20        11      Yes  Mobility/Recovery      15.0  2.0
# 11  2018-07-20        11      Yes  Mobility/Recovery      15.0  2.0
# 12  2018-07-20        13      Yes               Game      27.0  6.0
# ...
